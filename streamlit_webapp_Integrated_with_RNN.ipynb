# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmaharshi30/rnn-streamlit-webapp-deployment/blob/main/streamlit_webapp_Integrated_with_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Streamlit Webapp Integrated with RNN

# %%
print("Hello Harish i am saved in google drive")
# Out:
# Hello Harish i am saved in google drive
